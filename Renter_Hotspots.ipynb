# %%
import folium 
from folium import plugins
import ipywidgets
import geocoder
import geopy
import numpy as np
import pandas as pd
#from vega_datasets import data as vds

#folium.Map() To create a map

# %%
# To map with location start point, zoom level, size, and distance scale
renter_map = folium.Map(location=[51.509865, -0.118092], zoom_start=12, width=750, height=400, control_scale=True)
renter_map

# To save map
#Renter_map.save("C:\Users\Public\Desktop\Renter_map.html")
Renter_map.save('Renter_map.html')
# Out:
#   File "<ipython-input-36-84bded2de806>", line 6
#     Renter_map.save("C:\Users\Public\Desktop\Renter_map.html")
#                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# show map types using ipywidgets

# widget
select_widget=ipywidgets.Select(
    options=['Open Street Map', 'Terrain', 'Toner', 'Watercolor', 'Positron', 'Dark Matter'],
    value='Open Street Map',
    description='Map Type:',
    disabled=False)

# widget function
def select(map_type):
    if map_type == 'Open Street Map':
        display(folium.Map(location=[51.509865, -0.118092], zoom_start=12, height=500))
    if map_type == 'Terrain':
        display(folium.Map(location=[51.509865, -0.118092], tiles='Stamen Terrain', zoom_start=12, height=400))
    if map_type == 'Toner':
        display(folium.Map(location=[51.509865, -0.118092], tiles='Stamen Toner', zoom_start=12, height=400))
    if map_type == 'Watercolor':
        display(folium.Map(location=[51.509865, -0.118092], tiles='Stamen Watercolor', zoom_start=12, height=400))
    if map_type == 'Positron':
        display(folium.Map(location=[51.509865, -0.118092], tiles='CartoDB Positron', zoom_start=12, height=400))
    if map_type == 'Dark Matter':
        display(folium.Map(location=[51.509865, -0.118092], tiles='CartoDB Dark_Matter', zoom_start=12, height=400))
        
# interaction between widgets and function    
ipywidgets.interact(select, map_type=select_widget)
# Out:
# interactive(children=(Select(description='Map Type:', options=('Open Street Map', 'Terrain', 'Toner', 'Waterco…
# <function __main__.select(map_type)>

# %%
# mini map, scroll zoom toggle button, full screen

# map
map_with_mini = folium.Map(location=([51.509865, -0.118092]), zoom_start=12)

# plugin for mini map
minimap = plugins.MiniMap(toggle_display=True)

# add minimap to map
map_with_mini.add_child(minimap)

# add scroll zoom toggler to map
plugins.ScrollZoomToggler().add_to(map_with_mini)

# add full screen button to map
plugins.Fullscreen(position='topright').add_to(map_with_mini)

# display map
map_with_mini
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# geocode address and place marker on map

# map
Hot_map = folium.Map(location=[51.509865, -0.118092], zoom_start=12)

# get location information for address
#address = geocoder.osm('2920 Zoo Dr, San Diego, CA 92101')

# address latitude and longitude
address_latlng = [51.499226, -0.227835]

# add marker to map
folium.Marker(address_latlng, popup='Property1', tooltip='click').add_to(Hot_map)

# display map
Hot_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
renters  = pd.read_csv(r"C:\Users\Jamal\Documents\Data Analysis\LetCheck Jobs Analysis\LCOCTJOBS.xlsx")
renters.head
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-49-6510219f3e23> in <module>
# ----> 1 renters  = pd.read_csv(r"C:\Users\Jamal\Documents\Data Analysis\LetCheck Jobs Analysis\LCOCTJOBS.xlsx")
#       2 renters.head
#
# ...
